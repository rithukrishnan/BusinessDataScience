# %% [markdown]
# # Business Data Science  - Assignment 1
# ## Team Members
# 1.
# 2.
# 3.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('PatientData.csv', header=None, na_values='?')
# df.head()

x = 1
for col in df.columns:
  name = 'Column '+str(x)
  df = df.rename(columns={col:name})
  x = x+1

df[df.columns[13:]]
df['Column 1'].dtype.name
# Out:
# 'int64'

# %% [markdown]
# ### Part a -

# %%
num_of_features = len(df.iloc[0]) - 1 #Since the last column in the csv file is condition
num_of_patients = len(df) 

# df = df.replace("?",np.nan)

print("Number of Features -", num_of_features)
print("Number of Patients -", num_of_patients)
# Out:
# Number of Features - 279
# Number of Patients - 452

# %% [markdown]
# Therefore, the number of patients = 452, and the number of features = 279

# %% [markdown]
# ### Part b -

# %%
df.plot(y='Column 1', figsize = (15,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(y='Column 2', kind ='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(y='Column 3', figsize = (15,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(y='Column 4', figsize = (15,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1. The Plot for Column 1 is varying between 0 and 80, so this seems like the age of the patients
# 2. The Plot for column 2 is alternating between '0' and '1', so this might be gender
# 3. The plot for Column 3 seems to be for Blood Pressure
# 4. The plot for Column 4 seems to be for Heart Rate

# %% [markdown]
# ### Part c -

# %%
new_df = df.fillna(df.mean())
new_df
# Out:
#      Column 1  Column 2  Column 3  Column 4  Column 5  Column 6  Column 7  \
# 0          75         0       190        80        91       193       371
# 1          56         1       165        64        81       174       401
# 2          54         0       172        95       138       163       386
# 3          55         0       175        94       100       202       380
# 4          75         0       190        80        88       181       360
# ..        ...       ...       ...       ...       ...       ...       ...
# 447        53         1       160        70        80       199       382
# 448        37         0       190        85       100       137       361
# 449        36         0       166        68       108       176       365
# 450        32         1       155        55        93       106       386
# 451        78         1       160        70        79       127       364
#
#      Column 8  Column 9  Column 10  ...  Column 271  Column 272  Column 273  \
# ...

# %% [markdown]
# ### Part d -

# %%
df.corr().sort_values(by=['Column 280'], ascending=False)['Column 280']
# Out:
# Column 280    1.000000
# Column 91     0.368876
# Column 5      0.323879
# Column 93     0.313982
# Column 103    0.282523
#                 ...
# Column 158         NaN
# Column 165         NaN
# Column 205         NaN
# Column 265         NaN
# Column 275         NaN
# Name: Column 280, Length: 280, dtype: float64

# %% [markdown]
# There are various ways to determine feature importance and this is an active area of ma-chine learning study. Possible ways to determine importance include using decision trees(e.g. xgboost feature selection), f scores, pca/lda (largest eigenvalue eigenvectors), highestcorrelation or mutual information with output variable, standardized regression coefficients,change in Rˆ2/other metrics as variable is added to rest of variables, and others. Dependingon which methods you use, you can determine that different features are most important.At the end of the day, the goal is to predict the output variable while minimizing (or maxi-mizing) some metric, so pick all or some features that help with this.
