# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_squared_error

df_train = pd.read_csv('train_final.csv')
df_test = pd.read_csv('test_final.csv')

# %%
target = df_train["Y"]
id = df_test["Id"].values

df_train.drop(['Id','Y'],axis=1,inplace=True)
df_test.drop(['Id'],axis=1,inplace=True)

# %%
print('Binary features summary statistics')
df_train.describe().T.style.bar(subset = ['mean'], color = 'grey').bar(subset = ['std'],color = 'grey').background_gradient(cmap = 'GnBu')
# Out:
# Binary features summary statistics
# <style type="text/css">
# #T_a97b0_row0_col0, #T_a97b0_row0_col4, #T_a97b0_row0_col5, #T_a97b0_row0_col6, #T_a97b0_row0_col7, #T_a97b0_row1_col0, #T_a97b0_row1_col4, #T_a97b0_row1_col5, #T_a97b0_row1_col6, #T_a97b0_row1_col7, #T_a97b0_row2_col0, #T_a97b0_row2_col4, #T_a97b0_row2_col5, #T_a97b0_row2_col6, #T_a97b0_row3_col0, #T_a97b0_row3_col4, #T_a97b0_row3_col5, #T_a97b0_row3_col6, #T_a97b0_row3_col7, #T_a97b0_row4_col0, #T_a97b0_row4_col4, #T_a97b0_row4_col5, #T_a97b0_row4_col6, #T_a97b0_row4_col7, #T_a97b0_row5_col0, #T_a97b0_row5_col4, #T_a97b0_row5_col5, #T_a97b0_row5_col6, #T_a97b0_row5_col7, #T_a97b0_row6_col0, #T_a97b0_row6_col4, #T_a97b0_row6_col5, #T_a97b0_row6_col6, #T_a97b0_row6_col7, #T_a97b0_row7_col0, #T_a97b0_row7_col4, #T_a97b0_row7_col5, #T_a97b0_row7_col6, #T_a97b0_row7_col7, #T_a97b0_row8_col0, #T_a97b0_row8_col4, #T_a97b0_row8_col5, #T_a97b0_row8_col6, #T_a97b0_row8_col7, #T_a97b0_row9_col0, #T_a97b0_row9_col4, #T_a97b0_row9_col5, #T_a97b0_row9_col6, #T_a97b0_row9_col7, #T_a97b0_row10_col0, #T_a97b0_row10_col4, #T_a97b0_row10_col5, #T_a97b0_row10_col6, #T_a97b0_row10_col7, #T_a97b0_row11_col0, #T_a97b0_row11_col4, #T_a97b0_row11_col5, #T_a97b0_row11_col6, #T_a97b0_row11_col7, #T_a97b0_row12_col0, #T_a97b0_row12_col4, #T_a97b0_row12_col5, #T_a97b0_row12_col6, #T_a97b0_row12_col7, #T_a97b0_row13_col0, #T_a97b0_row13_col4, #T_a97b0_row13_col5, #T_a97b0_row13_col6, #T_a97b0_row13_col7, #T_a97b0_row14_col0, #T_a97b0_row14_col4, #T_a97b0_row14_col5, #T_a97b0_row14_col6, #T_a97b0_row14_col7, #T_a97b0_row15_col0, #T_a97b0_row15_col4, #T_a97b0_row15_col5, #T_a97b0_row15_col6, #T_a97b0_row15_col7, #T_a97b0_row16_col0, #T_a97b0_row16_col4, #T_a97b0_row16_col5, #T_a97b0_row16_col6, #T_a97b0_row16_col7, #T_a97b0_row17_col0, #T_a97b0_row17_col4, #T_a97b0_row17_col5, #T_a97b0_row17_col6, #T_a97b0_row17_col7, #T_a97b0_row18_col0, #T_a97b0_row18_col4, #T_a97b0_row18_col5, #T_a97b0_row18_col6, #T_a97b0_row18_col7, #T_a97b0_row19_col0, #T_a97b0_row19_col4, #T_a97b0_row19_col5, #T_a97b0_row19_col6, #T_a97b0_row19_col7, #T_a97b0_row20_col0, #T_a97b0_row20_col4, #T_a97b0_row20_col5, #T_a97b0_row20_col6, #T_a97b0_row20_col7, #T_a97b0_row21_col0, #T_a97b0_row21_col4, #T_a97b0_row21_col5, #T_a97b0_row21_col6, #T_a97b0_row21_col7, #T_a97b0_row22_col0, #T_a97b0_row22_col4, #T_a97b0_row22_col5, #T_a97b0_row22_col6, #T_a97b0_row22_col7, #T_a97b0_row23_col0, #T_a97b0_row23_col4, #T_a97b0_row23_col5, #T_a97b0_row23_col6, #T_a97b0_row23_col7, #T_a97b0_row24_col0, #T_a97b0_row24_col4, #T_a97b0_row24_col5, #T_a97b0_row24_col6, #T_a97b0_row24_col7, #T_a97b0_row25_col0, #T_a97b0_row25_col4, #T_a97b0_row25_col5, #T_a97b0_row25_col6, #T_a97b0_row25_col7, #T_a97b0_row26_col0, #T_a97b0_row26_col4, #T_a97b0_row26_col5, #T_a97b0_row26_col6, #T_a97b0_row26_col7, #T_a97b0_row27_col0, #T_a97b0_row27_col4, #T_a97b0_row27_col5, #T_a97b0_row27_col6, #T_a97b0_row27_col7, #T_a97b0_row28_col0, #T_a97b0_row28_col4, #T_a97b0_row28_col5, #T_a97b0_row28_col6, #T_a97b0_row28_col7, #T_a97b0_row29_col0, #T_a97b0_row29_col4, #T_a97b0_row29_col5, #T_a97b0_row29_col6, #T_a97b0_row29_col7, #T_a97b0_row30_col0, #T_a97b0_row30_col4, #T_a97b0_row30_col5, #T_a97b0_row30_col6, #T_a97b0_row30_col7, #T_a97b0_row31_col0, #T_a97b0_row31_col4, #T_a97b0_row31_col5, #T_a97b0_row31_col6, #T_a97b0_row31_col7, #T_a97b0_row32_col0, #T_a97b0_row32_col4, #T_a97b0_row32_col5, #T_a97b0_row32_col6, #T_a97b0_row32_col7, #T_a97b0_row33_col0, #T_a97b0_row33_col4, #T_a97b0_row33_col5, #T_a97b0_row33_col6, #T_a97b0_row33_col7, #T_a97b0_row34_col0, #T_a97b0_row34_col4, #T_a97b0_row34_col5, #T_a97b0_row34_col6, #T_a97b0_row34_col7, #T_a97b0_row35_col0, #T_a97b0_row35_col4, #T_a97b0_row35_col5, #T_a97b0_row35_col6, #T_a97b0_row35_col7, #T_a97b0_row36_col0, #T_a97b0_row36_col4, #T_a97b0_row36_col5, #T_a97b0_row36_col6, #T_a97b0_row36_col7, #T_a97b0_row37_col0, #T_a97b0_row37_col4, #T_a97b0_row37_col5, #T_a97b0_row37_col6, #T_a97b0_row37_col7, #T_a97b0_row38_col0, #T_a97b0_row38_col4, #T_a97b0_row38_col5, #T_a97b0_row38_co ...

# %%
# drop_zeros = ['6','30','35', '40', '60','80', '90', '101','102', '113', '118', '129', '138', '142','163', '206', '216', '233', '239', '247','250', '253', '259', '305', '307', '315', '322', '323', '333', '350', '364', '120', '208']

# df_train =  df_train.drop(drop_zeros,axis=1)        
# df_test = df_test.drop(drop_zeros,axis=1)
#log transform skewed numeric features:
# from scipy.stats import skew

# skewed_feats = df_train.apply(lambda x: skew(x.dropna())) #compute skewness
# skewed_feats = skewed_feats[skewed_feats > 0.75]
# skewed_feats = skewed_feats.index

# df_train[skewed_feats] = np.log1p(df_train[skewed_feats])
# # skewed_feats
# df_train[['63','132', '382','198', '146']] = np.log1p(df_train[['63','132', '382','198', '146']])
# df_test[['63','132', '382','198', '146']] = np.log1p(df_test[['63','132', '382','198', '146']])

# %%
from sklearn import preprocessing

#columns = ['4','63','132', '146', '180','382', '119', '198', '379']
columns = ['4','180',  '379']

scale_train = preprocessing.RobustScaler().fit(df_train[columns])
df_train[columns] = scale_train.transform(df_train[columns])

scale_test = preprocessing.RobustScaler().fit(df_test[columns])
df_test[columns] = scale_test.transform(df_test[columns])

minmax_scale_train = preprocessing.MinMaxScaler().fit(df_train[columns])
df_train[columns] = minmax_scale_train.transform(df_train[columns])

minmax_scale_test = preprocessing.MinMaxScaler().fit(df_test[columns])
df_test[columns] = minmax_scale_test.transform(df_test[columns])

# %%
x_train, x_test, y_train, y_test = train_test_split(df_train, target, test_size=0.33, random_state=1)

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score

para = { 'learning_rate': 0.02, 'iterations': 1000, 'depth': 9,  "verbose":0,  "class_weights":[0.55,0.45]}

catboost = CatBoostClassifier(**para)

catboost.fit(df_train, target)

y_proba = catboost.predict_proba(x_test)
print(roc_auc_score(y_test, y_proba[:,1]))



y_pred = catboost.predict(x_test)

score = (accuracy_score(y_test, y_pred)) * 100
print("Accuracy score is %.2f%%" % score)

score = cross_val_score(catboost, df_train, target)
print ("Cross validation score for catboost: ",np.mean(score)*100)
# Out:
# 1.0
# Accuracy score is 100.00%
# Cross validation score for catboost:  84.17267089915843

# %%
# 0.996910943148209
# Accuracy score is 97.44%

plot_roc_curve(catboost, x_test, y_test, name = 'CatBoost')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metrics.RocCurveDisplay.from_predictions` or :meth:`sklearn.metrics.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %%
sub_proba = catboost.predict_proba(df_test)
pred_col=np.c_[id,sub_proba[:,1]]

submission = pd.DataFrame(pred_col, columns = ['Id','Y'])
submission["Id"] = submission["Id"].astype("Int32")
submission
# Out:
#         Id         Y
# 0     2604  0.011870
# 1     2605  0.044150
# 2     2606  0.025579
# 3     2607  0.005373
# 4     2608  0.685831
# ...    ...       ...
# 3599  6203  0.102152
# 3600  6204  0.016301
# 3601  6205  0.006027
# 3602  6206  0.033701
# 3603  6207  0.008456
#
# [3604 rows x 2 columns]

# %%
submission.to_csv('lastdaypart3submission.csv', index=False)
