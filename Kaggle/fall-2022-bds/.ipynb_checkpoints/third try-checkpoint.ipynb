# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_squared_error

df_train = pd.read_csv('train_final.csv')
df_test = pd.read_csv('test_final.csv')

# %%
target = df_train["Y"]
id = df_test["Id"].values

df_train.drop(['Id','Y'],axis=1,inplace=True)
df_test.drop(['Id'],axis=1,inplace=True)

# %%
print('Binary features summary statistics')
df_train.describe().T.style.bar(subset = ['mean'], color = 'grey').bar(subset = ['std'],color = 'grey').background_gradient(cmap = 'GnBu')
# Out:
# Binary features summary statistics
# <style type="text/css">
# #T_e5e8d_row0_col0, #T_e5e8d_row0_col4, #T_e5e8d_row0_col5, #T_e5e8d_row0_col6, #T_e5e8d_row0_col7, #T_e5e8d_row1_col0, #T_e5e8d_row1_col4, #T_e5e8d_row1_col5, #T_e5e8d_row1_col6, #T_e5e8d_row1_col7, #T_e5e8d_row2_col0, #T_e5e8d_row2_col4, #T_e5e8d_row2_col5, #T_e5e8d_row2_col6, #T_e5e8d_row3_col0, #T_e5e8d_row3_col4, #T_e5e8d_row3_col5, #T_e5e8d_row3_col6, #T_e5e8d_row3_col7, #T_e5e8d_row4_col0, #T_e5e8d_row4_col4, #T_e5e8d_row4_col5, #T_e5e8d_row4_col6, #T_e5e8d_row4_col7, #T_e5e8d_row5_col0, #T_e5e8d_row5_col4, #T_e5e8d_row5_col5, #T_e5e8d_row5_col6, #T_e5e8d_row5_col7, #T_e5e8d_row6_col0, #T_e5e8d_row6_col4, #T_e5e8d_row6_col5, #T_e5e8d_row6_col6, #T_e5e8d_row6_col7, #T_e5e8d_row7_col0, #T_e5e8d_row7_col4, #T_e5e8d_row7_col5, #T_e5e8d_row7_col6, #T_e5e8d_row7_col7, #T_e5e8d_row8_col0, #T_e5e8d_row8_col4, #T_e5e8d_row8_col5, #T_e5e8d_row8_col6, #T_e5e8d_row8_col7, #T_e5e8d_row9_col0, #T_e5e8d_row9_col4, #T_e5e8d_row9_col5, #T_e5e8d_row9_col6, #T_e5e8d_row9_col7, #T_e5e8d_row10_col0, #T_e5e8d_row10_col4, #T_e5e8d_row10_col5, #T_e5e8d_row10_col6, #T_e5e8d_row10_col7, #T_e5e8d_row11_col0, #T_e5e8d_row11_col4, #T_e5e8d_row11_col5, #T_e5e8d_row11_col6, #T_e5e8d_row11_col7, #T_e5e8d_row12_col0, #T_e5e8d_row12_col4, #T_e5e8d_row12_col5, #T_e5e8d_row12_col6, #T_e5e8d_row12_col7, #T_e5e8d_row13_col0, #T_e5e8d_row13_col4, #T_e5e8d_row13_col5, #T_e5e8d_row13_col6, #T_e5e8d_row13_col7, #T_e5e8d_row14_col0, #T_e5e8d_row14_col4, #T_e5e8d_row14_col5, #T_e5e8
8d_row32_col4, #T_e5e8d_row32_col5, #T_e5e8d_row32_col6, #T_e5e8d_row32_col7, #T_e5e8d_row33_col0, #T_e5e8d_row33_col4, #T_e5e8d_row33_col5, #T_e5e8d_row33_col6, #T_e5e8d_row33_col7, #T_e5e8d_row34_col0, #T_e5e8d_row34_col4, #T_e5e8d_row34_col5, #T_e5e8d_row34_col6, #T_e5e8d_row34_col7, #T_e5e8d_row35_col0, #T_e5e8d_row35_col4, #T_e5e8d_row35_col5, #T_e5e8d_row35_col6, #T_e5e8d_row35_col7, #T_e5e8d_row36_col0, #T_e5e8d_row36_col4, #T_e5e8d_row36_col5, #T_e5e8d_row36_col6, #T_e5e8d_row36_col7, #T_e5e8d_row37_col0, #T_e5e8d_row37_col4, #T_e5e8d_row37_col5, #T_e5e8d_row37_col6, #T_e5e8d_row37_col7, #T_e5e8d_row38_col0, #T_e5e8d_row38_col4, #T_e5e8d_row38_col5, #T_e5e8d_row38_co ...

# %%
from sklearn import preprocessing

columns = ['4','63','132', '146', '180','382', '119', '198', '379']
minmax_scale_train = preprocessing.MinMaxScaler().fit(df_train[columns])
df_train[columns] = minmax_scale_train.transform(df_train[columns])

minmax_scale_test = preprocessing.MinMaxScaler().fit(df_test[columns])
df_test[columns] = minmax_scale_test.transform(df_test[columns])

# %%
x_train, x_test, y_train, y_test = train_test_split(df_train, target, test_size=0.33, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
log_reg=LogisticRegression(solver='liblinear').fit(x_train,y_train)

# %%
plot_roc_curve(log_reg, x_test, y_test, name = 'Logistic Regression')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metrics.RocCurveDisplay.from_predictions` or :meth:`sklearn.metrics.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %%
y_proba = log_reg.predict_proba(x_test)
roc_auc_score(y_test, y_proba[:,1])
# Out:
# 0.6622329937561617

# %%
from catboost import CatBoostClassifier

catboost = CatBoostClassifier(iterations=500, 
                 learning_rate=0.03, depth=6, verbose=0)

catboost.fit(x_train, y_train)

# %%
plot_roc_curve(catboost, x_test, y_test, name = 'CatBoost')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metrics.RocCurveDisplay.from_predictions` or :meth:`sklearn.metrics.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %%
y_proba = catboost.predict_proba(x_test)
roc_auc_score(y_test, y_proba[:,1])
# Out:
# 0.8800115018074268

# %%
# sub_proba = catboost.predict_proba(df_test)
# pred_col=np.c_[id,sub_proba[:,1]]

# submission = pd.DataFrame(pred_col, columns = ['Id','Y'])
# submission["Id"] = submission["Id"].astype("Int32")
# submission

# %%
# submission.to_csv('submission.csv', index=False)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=150)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=150)

# %%
plot_roc_curve(rf, x_test, y_test, name = 'Random Forest')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metrics.RocCurveDisplay.from_predictions` or :meth:`sklearn.metrics.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %%
y_proba = rf.predict_proba(x_test)
roc_auc_score(y_test, y_proba[:,1])
# Out:
# 0.7422568189286888

# %%
import xgboost as xgb

xgb = xgb.XGBClassifier(n_estimators=100)

xgb.fit(x_train, y_train)

plot_roc_curve(xgb, x_test, y_test, name = 'xgb')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metrics.RocCurveDisplay.from_predictions` or :meth:`sklearn.metrics.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
